# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1 , 2, 3, 4, 5])
y = x**2 + 3

# %%
y
# Out:
# array([ 4,  7, 12, 19, 28], dtype=int32)

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
plt.style.use('seaborn')

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y ,c = 'red', label = "Stock Price")
plt.title("My Graph")
plt.legend()
plt.show()

# %%
plt.plot(x,y, label = "Stock Price")
plt.plot(x,x**2, label = "Market Price")
plt.scatter(np.array([3 , 6, 8]) , np.array([4 , 2, 5]) , c = 'red')
plt.title("My Graph")
plt.legend()
plt.show()

# %%
plt.scatter(x,y, label = "Stock Price")
plt.scatter(x,x**2, label = "Market Price")
plt.title("My Graph")
plt.legend()
plt.show()
