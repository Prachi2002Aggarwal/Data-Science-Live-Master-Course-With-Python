# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
bottom_left = cv2.imread('D:/Data Science/Own practice using videos given by CB/Data Science Quickstart Mode/images for Challenge - Instagram Style Photo Collage/bottom_left.jpg')
bottom_left = cv2.cvtColor(bottom_left,cv2.COLOR_BGR2RGB)

# %%
bottom_right = cv2.imread('D:/Data Science/Own practice using videos given by CB/Data Science Quickstart Mode/images for Challenge - Instagram Style Photo Collage/bottom_right.jpg')
bottom_right = cv2.cvtColor(bottom_right,cv2.COLOR_BGR2RGB)

# %%
center = cv2.imread('D:/Data Science/Own practice using videos given by CB/Data Science Quickstart Mode/images for Challenge - Instagram Style Photo Collage/center.jpeg')
center = cv2.cvtColor(center,cv2.COLOR_BGR2RGB)

# %%
top_right = cv2.imread('D:/Data Science/Own practice using videos given by CB/Data Science Quickstart Mode/images for Challenge - Instagram Style Photo Collage/top_right.jpg')
top_right = cv2.cvtColor(top_right,cv2.COLOR_BGR2RGB)

# %%
top_left = cv2.imread('D:/Data Science/Own practice using videos given by CB/Data Science Quickstart Mode/images for Challenge - Instagram Style Photo Collage/top_left.jpg')
top_left = cv2.cvtColor(top_left,cv2.COLOR_BGR2RGB)

# %%
print(bottom_left)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
print(bottom_right)
# Out:
# [[[ 79 197 171]
#   [ 84 202 176]
#   [ 92 210 184]
#   ...
#   [ 14 238   0]
#   [  9 234   0]
#   [  7 232   0]]
#
#  [[ 93 211 185]
#   [ 97 215 189]
#   [103 221 195]
#   ...
#   [ 15 239   0]
#   [ 11 234   0]
#   [  8 233   0]]
#
#  [[112 230 204]
#   [114 232 206]
#   [118 236 210]
#   ...
#   [ 15 238   0]
#   [ 12 235   0]
#   [ 10 233   0]]
#
#  ...
#
#  [[  0 189  19]
#   [  0 192  19]
#   [  3 198  20]
#   ...
#   [  0 111  86]
#   [  0 108  85]
#   [  0 108  85]]
#
#  [[  0 183  16]
#   [  0 187  17]
#   [  0 192  18]
#   ...
#   [  0 109  84]
#   [  0 106  82]
#   [  0 106  82]]
#
#  [[  0 180  13]
#   [  0 184  14]
#   [  0 189  17]
#   ...
#   [  0 108  83]
#   [  0 106  82]
#   [  0 105  81]]]

# %%
print(top_right)
# Out:
# [[[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  ...
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]]

# %%
print(top_left)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
print(center)
# Out:
# [[[157 157 157]
#   [158 158 158]
#   [158 158 158]
#   ...
#   [203 203 203]
#   [202 202 202]
#   [201 201 201]]
#
#  [[158 158 158]
#   [158 158 158]
#   [158 158 158]
#   ...
#   [203 203 203]
#   [203 203 203]
#   [201 201 201]]
#
#  [[158 158 158]
#   [158 158 158]
#   [159 159 159]
#   ...
#   [203 203 203]
#   [203 203 203]
#   [202 202 202]]
#
#  ...
#
#  [[195 193 194]
#   [195 193 194]
#   [195 193 194]
#   ...
#   [194 194 194]
#   [194 194 194]
#   [193 193 193]]
#
#  [[194 192 193]
#   [195 193 194]
#   [195 193 194]
#   ...
#   [194 194 194]
#   [193 193 193]
#   [193 193 193]]
#
#  [[191 191 191]
#   [191 191 191]
#   [192 192 192]
#   ...
#   [194 194 194]
#   [193 193 193]
#   [192 192 192]]]

# %%
bottom_right.shape
# Out:
# (300, 300, 3)

# %%
bottom_left = cv2.resize(bottom_left, (200,200))
bottom_right = cv2.resize(bottom_right, (200,200))
top_left = cv2.resize(top_left, (200,200))
top_right = cv2.resize(top_right, (200,200))
temp = cv2.resize(center, (100,100))

# %%
temp.shape
# Out:
# (100, 100, 3)

# %%
center.shape
# Out:
# (225, 225, 3)

# %%
a = np.zeros(shape=(430,430,3), dtype = 'int64')

# %%
plt.imshow(a)
plt.show()

# %%
a[10:210, 10:210] = top_left

# %%
plt.imshow(a)
plt.show()

# %%
a[10:210, 220:420] = top_right

# %%
plt.imshow(a)
plt.show()

# %%
a[220:420, 220:420] = bottom_right

# %%
plt.imshow(a)
plt.show()

# %%
a[220:420, 10:210] = bottom_left

# %%
plt.imshow(a)
plt.show()

# %%
a[170:270, 170:270] = temp

# %%
sample = cv2.imread('D:/Data Science/Own practice using videos given by CB/Data Science Quickstart Mode/images for Challenge - Instagram Style Photo Collage/sample_image.jpg')
sample = cv2.cvtColor(sample,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(sample)
plt.show()

# %%
plt.imshow(a)
plt.show()

# %%
a[100:110,100:320] = (0 , 0 , 0)

# %%
plt.imshow(a)
plt.show()

# %%
a[310:320,100:320] = (0 , 0 , 0)

# %%
plt.imshow(a)
plt.show()

# %%
a[100:320,100:110] = (0 , 0 , 0)

# %%
plt.imshow(a)
plt.show()

# %%
a[100:320,310:320] = (0 , 0 , 0)

# %%
plt.imshow(a)
plt.show()

# %%
# %matplotlib inline
plt.imshow(a)
plt.axis("off")
plt.show()

# %%
a.shape
# Out:
# (430, 430, 3)

# %%
r = a[:,:,0].reshape(-1,1)

# %%
r.shape
# Out:
# (184900, 1)

# %%
g = a[:,:,1].reshape(-1,1)

# %%
b = a[:,:,2].reshape(-1,1)

# %%
g.shape , b.shape
# Out:
# ((184900, 1), (184900, 1))

# %%
final = np.concatenate([r,g,b] , axis = 1)

# %%
final.shape
# Out:
# (184900, 3)

# %%
df = pd.DataFrame(final , columns = ['r','g','b'])

# %%
df
# Out:
#         r  g  b
# 0       0  0  0
# 1       0  0  0
# 2       0  0  0
# 3       0  0  0
# 4       0  0  0
# ...    .. .. ..
# 184895  0  0  0
# 184896  0  0  0
# 184897  0  0  0
# 184898  0  0  0
# 184899  0  0  0
#
# [184900 rows x 3 columns]

# %%
df.to_csv('final.csv' , index = False , header = True)

# %%
df.to_csv?

# %%
# a.shape
# img = Image.fromarray(a, 'RGB')

# %%
# df = pd.DataFrame(a, columns = ['r','g','b'])
# plt.imshow(a)
# plt.show()

# %%
# a = cv2.imread('D:/Data Science/Own practice using videos given by CB/Data Science Quickstart Mode/images for Challenge - Instagram Style Photo Collage/final.png')
# a = cv2.cvtColor(a,cv2.COLOR_BGR2RGB)

# %%
# stacked = pd.Panel(a.swapaxes(1,2)).to_frame().stack().reset_index()
# stacked.columns = ['r', 'g', 'b']
# # save to disk
# stacked.to_csv('stacked.csv', index=False)

# %%
# %matplotlib inline
# plt.imshow(a)
# plt.axis("off")
# plt.show()

# %%
# a.shape

# %%
# np.ravel(a)

# %%
# from PIL import Image
# import numpy as gfg
 
# # read an image
# img = a
 
# # convert image object into array
# imageToMatrice = gfg.asarray(img)
 
# # printing shape of image
# print(imageToMatrice.shape)

# %%
# imageToMatrice[230:240]

# %%
# plt.imshow(imageToMatrice)
# plt.axis("off")
# plt.show()

# %%
# from scipy import misc
# arr = a # 640x480x3 array
# arr[20, 30] # 3-vector for a pixel
# arr[20, 30, 1]

# %%
# a[230:240]

# %%
# from PIL import Image
# import numpy as np

# img = Image.open('D:/Data Science/Own practice using videos given by CB/Data Science Quickstart Mode/images for Challenge - Instagram Style Photo Collage/final.png')
# print('Inspect a few pixels in the original image:')
# for y in np.arange(3):
#     for x in np.arange(3):
#         print(x, y, img.getpixel((x, y)))

# # Modified for RGB images from: https://stackoverflow.com/a/60783743/11089932
# img_np = np.array(img)
# xy_coords = np.flip(np.column_stack(np.where(np.all(img_np >= 0, axis=2))), axis=1)
# # rgb = np.reshape(img_np, (np.prod(img_np.shape[:2]), 4))

# # # Add pixel numbers in front
# # pixel_numbers = np.expand_dims(np.arange(1, xy_coords.shape[0] + 1), axis=1)
# # value = np.hstack([pixel_numbers, xy_coords, rgb])
# # print('\nCompare pixels in result:')
# # for y in np.arange(3):
# #     for x in np.arange(3):
# #         print(value[(value[:, 1] == x) & (value[:, 2] == y)])

# # # Properly save as CSV
# # np.savetxt("outputdata.csv", value, delimiter='\t', fmt='%4d')
# print(img_np)

# %%
# plt.imshow(img)
# plt.axis("off")
# plt.show()

# %%
# img.shape

# %%
# a.shape

# %%
# type(a)

# %%
# import pandas as pd
# arr = a

# %%
# DF = pd.DataFrame(arr)
# DF.to_csv("data1.csv")

# %%
# img=img.reshape(184900,3)
